# %%
from city_road_network.downloaders.stats import download_nhts_data, get_russtat_data, get_nhts_dataset
import pandas as pd

# %%
df_trips = get_nhts_dataset("trippub.csv")

# %%
df = get_russtat_data()
df
# Out:
# MOSCOW??? {'region': 'г. Москва - городские населенные пункты', 'hh_count': 6221846.0, 'pop_count': 12960115.0, 'hh_size_1': 3227775.0, 'hh_size_2': 1158173.0, 'hh_size_3': 833272.0, 'hh_size_4': 527374.0, 'hh_size_5': 263806.0, 'hh_size_6': 211446.0, 'hh_size_6_count': 1487652.0, 'avg_hh_size': 2.1}
# MOSCOW??? {'region': 'г. Санкт-Петербург - городские населенные пункты', 'hh_count': 2696737.0, 'pop_count': 5559650.0, 'hh_size_1': 1283573.0, 'hh_size_2': 611942.0, 'hh_size_3': 401977.0, 'hh_size_4': 245721.0, 'hh_size_5': 98545.0, 'hh_size_6': 54979.0, 'hh_size_6_count': 370653.0, 'avg_hh_size': 2.1}
#                            region    hh_count    pop_count   hh_size_1  \
# 0            Российская Федерация  66061419.0  146148111.0  27629392.0
# 1   Центральный федеральный округ  19117780.0   40060671.0   8920045.0
# 2            Белгородская область    664189.0    1531558.0    240351.0
# 3                Брянская область    542370.0    1158565.0    229881.0
# 4            Владимирская область    649960.0    1332874.0    283076.0
# ..                            ...         ...          ...         ...
# 91               Амурская область    353739.0     755961.0    146672.0
# 92            Магаданская область     69998.0     134286.0     33876.0
# 93            Сахалинская область    225161.0     460093.0    101605.0
# 94  Еврейская автономная  область     69041.0     146939.0     28365.0
# 95    Чукотский автономный  округ     21116.0      47299.0      8454.0
#
#      hh_size_2   hh_size_3  hh_size_4  hh_size_5  hh_size_6  hh_size_6_count  \
# 0   16478612.0  10330685.0  6986598.0  2846749.0  1789383.0       12389303.0
# 1    4409680.0   2852720.0  1765483.0   718003.0   451849.0        3111159.0
# 2     179313.0    119650.0    79002.0    28956.0    16917.0         112843.0
# 3     143684.0     83769.0    55098.0    18898.0    11040.0          75127.0
# 4     177376.0    100803.0    61651.0    19282.0     7772.0          49623.0
# ..         ...         ...        ...        ...        ...              ...
# 91     94540.0     57779.0    36562.0    12408.0     5778.0          38584.0
# 92     18193.0     10492.0     5504.0     1419.0      514.0           3437.0
# 93     58718.0     33762.0    20718.0     7214.0     3144.0          20824.0
# 94     19458.0     10999.0     6717.0     2302.0     1200.0           8283.0
# 95      5412.0      3504.0     2282.0      883.0      581.0           3966.0
#
#     avg_hh_size  avg_city_hh_size
# 0           2.2               2.1
# 1           2.1               2.1
# 2           2.3               2.2
# 3           2.1               2.0
# 4           2.1               2.0
# ..          ...               ...
# 91          2.1               2.0
# 92          1.9               1.9
# 93          2.0               2.0
# 94          2.1               2.0
# 95          2.2               2.1
#
# [96 rows x 12 columns]
