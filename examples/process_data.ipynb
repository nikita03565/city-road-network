# %%
from city_road_network.downloaders.osm import get_relation_poly, get_osm_data
from city_road_network.utils.map import draw_boundaries, draw_zones
from city_road_network.writers.csv import save_osm_data
from city_road_network.processing.graph import process_edges
import pandas as pd

# %%
CITY_NAME = "moscow"

# %%
edges_df = process_edges(CITY_NAME)
edges_df
# Out:
# [2023-05-07 20:28:22,656][WARNING] Found unknown speed 20;60
# [2023-05-07 20:28:22,698][WARNING] Found unknown speed zone:30
# /home/nikita/Projects/city_road_network/city_road_network/processing/graph.py:93: DtypeWarning: Columns (22,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_edges = pd.read_csv(edgelist_file, dtype={"oneway": bool}, index_col=0)
# [2023-05-07 20:28:22,963][WARNING] Found unknown speed zone:30
# [2023-05-07 20:28:22,968][WARNING] Found unknown speed zone:50
# [2023-05-07 20:28:24,003][INFO] Saved dataframe to /home/nikita/Projects/city_road_network/data/moscow/edgelist_upd.csv
#         start_node     end_node                             osmid  \
# 0         27717690   3067941815                         302546139
# 1         28041755   2393697879                           8096919
# 2         28041755     59638521                          77472787
# 3         28041755     59638524                         134799812
# 4         28043165     86666643  [299748848, 299748851, 47234037]
# ...            ...          ...                               ...
# 35755  10870940112   4944191740                         504243046
# 35756  10870940113  10870940112                         504243046
# 35757  10870940113    288351101                        1169014189
# 35758  10870940117   2048383211                          46619107
# 35759  10870940117    288351101                         598386890
#
#               highway  surface  oneway lanes   length  \
# 0            tertiary  asphalt    True     1  453.861
# 1        unclassified  asphalt   False     1   24.324
# 2        unclassified  asphalt   False     2  290.314
# 3            tertiary  asphalt   False     2   91.705
# 4           secondary  asphalt   False     4  439.897
# ...               ...      ...     ...   ...      ...
# 35755       secondary  asphalt    True     2  187.834
# 35756       secondary  asphalt    True     2    8.676
# 35757         primary  asphalt    True     3   24.337
# 35758  secondary_link  asphalt    True     1   27.315
# 35759       secondary  asphalt    True     2   40.702
#
#                             name smoothness maxspeed area railway service  \
# 0                            NaN        NaN       60  NaN     NaN     NaN
# 1                            NaN        NaN       20  NaN     NaN     NaN
# 2                 Открытое шоссе       good       20  NaN     NaN     NaN
# 3                 Открытое шоссе        NaN       60  NaN     NaN     NaN
# 4                 Открытое шоссе       good       60  NaN     NaN     NaN
# ...                          ...        ...      ...  ...     ...     ...
# 35755             улица Вавилова        NaN       60  NaN     NaN     NaN
# 35756             улица Вавилова        NaN       60  NaN     NaN     NaN
# 35757  проспект 60-летия Октября        NaN       60  NaN     NaN     NaN
# 35758                        NaN        NaN       60  NaN     NaN     NaN
# 35759             улица Вавилова        NaN       60  NaN     NaN     NaN
#
#        length (m)  length (km)  capacity (veh/h)  maxspeed (km/h)  \
# 0         453.861     0.453861              1800               60
# 1          24.324     0.024324              1800               20
# 2         290.314     0.290314              1800               20
# 3          91.705     0.091705              1800               60
# 4         439.897     0.439897              1800               60
# ...           ...          ...               ...              ...
# 35755     187.834     0.187834              3600               60
# 35756       8.676     0.008676              3600               60
# 35757      24.337     0.024337              4000               60
# 35758      27.315     0.027315              1800               60
# 35759      40.702     0.040702              3600               60
#
#        flow_time (h)  flow_time (s)
# 0           0.007564       27.23166
# 1           0.001216        4.37832
# 2           0.014516       52.25652
# 3           0.001528        5.50230
# 4           0.007332       26.39382
# ...              ...            ...
# 35755       0.003131       11.27004
# 35756       0.000145        0.52056
# 35757       0.000406        1.46022
# 35758       0.000455        1.63890
# 35759       0.000678        2.44212
#
# [35760 rows x 20 columns]
